# %% [markdown]
# # Load trained StyleGAN model

# %%
#! /Users/rdua/opt/anaconda3/bin/pip install https://github.com/podgorskiy/dnnlib/releases/download/0.0.1/dnnlib-0.0.1-py3-none-any.whl
# Out:
# Collecting dnnlib==0.0.1 from https://github.com/podgorskiy/dnnlib/releases/download/0.0.1/dnnlib-0.0.1-py3-none-any.whl
#   Downloading https://github.com/podgorskiy/dnnlib/releases/download/0.0.1/dnnlib-0.0.1-py3-none-any.whl
# Installing collected packages: dnnlib
# Successfully installed dnnlib-0.0.1

# %%
#! /Users/rdua/opt/anaconda3/bin/pip install config
# Out:
# Collecting config
#   Downloading https://files.pythonhosted.org/packages/67/af/a7c8be986afee4cf277045cfdb06605296ff3f1a1de415d62c18a7a33040/config-0.5.0.post0-py2.py3-none-any.whl
# Installing collected packages: config
# Successfully installed config-0.5.0.post0

# %%
import os
import pprint
import pickle
import numpy as np
import PIL.Image
import dnnlib
import dnnlib.tflib as tflib
import config

import tensorflow as tf

# %%
import numpy as np
import collections
import tensorflow as tf
import pickle
import dnnlib.tflib as tflib

tflib.init_tf()
f = open('karras2019stylegan-ffhq-1024x1024.pkl', 'rb')
_G, _D, _Gs = pickle.load(f)
print('Gs ready')

# Load best weights (Gs) into memory
sess = tf.get_default_session()    
all_weights = collections.OrderedDict()
with sess.as_default():  
    for i, (key, weight_tensor) in enumerate(_Gs.vars.items()):        
        all_weights[key] = weight_tensor.eval()
        print('.', end='')
print(' ({}) weights found. '.format(len(all_weights)))
# Out:
# WARNING:tensorflow:From <string>:364: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Gs ready
# ................................................................................................................................................. (145) weights found.

# %% [markdown]
# # Save best weights (Gs) to disk

# %%
pickle.dump(all_weights, open( 'gs_weights.pkl', 'wb' ) )
print('Saved original StyleGAN weights to disk.')
# Out:
# Saved original StyleGAN weights to disk.

# %% [markdown]
# # Create our `tf.keras.Model` version of StyleGAN

# %%
import numpy as np
from stylegan import StyleGAN_G

model = StyleGAN_G()
# Out:
# WARNING:tensorflow:Entity <bound method PixelNorm.call of <stylegan.PixelNorm object at 0x7fd94a0e7f90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method PixelNorm.call of <stylegan.PixelNorm object at 0x7fd94a0e7f90>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method PixelNorm.call of <stylegan.PixelNorm object at 0x7fd94a0e7f90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method PixelNorm.call of <stylegan.PixelNorm object at 0x7fd94a0e7f90>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method DenseLayer.call of <stylegan.DenseLayer object at 0x7fd94a0e7b50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method DenseLayer.call of <stylegan.DenseLayer object at 0x7fd94a0e7b50>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method DenseLayer.call of <stylegan.DenseLayer object at 0x7fd94a0e7b50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method DenseLayer.call of <stylegan.DenseLayer object at 0x7fd94a0e7b50>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method DenseLayer.call of <stylegan.DenseLayer object at 0x7fd98bdbfe10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method DenseLayer.call of <stylegan.DenseLayer object at 0x7fd98bdbfe10>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method DenseLayer.call of <stylegan.DenseLayer object at 0x7fd98bdbfe10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method DenseLayer.call of <stylegan.DenseLayer object at 0x7fd98bdbfe10>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method DenseLayer.call of <stylegan.DenseLayer object at 0x7fd98bde65d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method DenseLayer.call of <stylegan.DenseLayer object at 0x7fd98bde65d0>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method DenseLayer.call of <stylegan.DenseLayer object at 0x7fd98bde65d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound
> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method RandomNoise.call of <stylegan.RandomNoise object at 0x7fd98be14950>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method RandomNoise.call of <stylegan.RandomNoise object at 0x7fd98be14950>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method RandomNoise.call of <stylegan.RandomNoise object at 0x7fd98be14950>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method RandomNoise.call of <stylegan.RandomNoise object at 0x7fd96b451850>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method RandomNoise.call of <stylegan.RandomNoise object at 0x7fd96b451850>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method RandomNoise.call of <stylegan.RandomNoise object at 0x7fd96b451850>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method RandomNoise.call of <stylegan.RandomNoise object at 0x7fd96b451850>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method RandomNoise.call of <stylegan.RandomNoise object at 0x7fd98bdfa690>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method RandomNoise.call of <stylegan.RandomNoise object at 0x7fd98bdfa690>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method RandomNoise.call of <stylegan.RandomNoise object at 0x7fd98bdfa690>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method RandomNoise.call of <stylegan.RandomNoise object at 0x7fd98bdfa690>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Const.call of <stylegan.Const object at 0x7fd94a759dd0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Const.call of <stylegan.Const object at 0x7fd94a759dd0>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Const.call of <stylegan.Const object at 0x7fd94a759dd0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Const.call of <stylegan.Const object at 0x7fd94a759dd0>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method ApplyNoise.call of <stylegan.ApplyNoise object at 0x7fd96b466bd0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method ApplyNoise.call of <stylegan.ApplyNoise object at 0x7fd96b466bd0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method ApplyNoise.call of <stylegan.ApplyNoise object at 0x7fd96b466bd0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method ApplyNoise.call of <stylegan.ApplyNoise object at 0x7fd96b466bd0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method ApplyBias.call of <stylegan.ApplyBias object at 0x7fd9795c0890>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method ApplyBias.call of <stylegan.ApplyBias object at 0x7fd9795c0890>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method ApplyBias.call of <stylegan.ApplyBias object at 0x7fd9795c0890>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method ApplyBias.call of <stylegan.ApplyBias object at 0x7fd9795c0890>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method InstanceNorm.call of <stylegan.InstanceNorm object at 0x7fd96b485390>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method InstanceNorm.call of <stylegan.InstanceNorm object at 0x7fd96b485390>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method InstanceNorm.call of <stylegan.InstanceNorm object at 0x7fd96b485390>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method InstanceNorm.call of <stylegan.InstanceNorm object at 0x7fd96b485390>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method StridedSlice.call of <stylegan.StridedSlice object at 0x7fd929cf2590>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method StridedSlice.call of <stylegan.StridedSlice object at 0x7fd929cf2590>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method StridedSlice.call of <stylegan.StridedSlice object at 0x7fd929cf2590>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method StridedSlice.call of <stylegan.StridedSlice object at 0x7fd929cf2590>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method DenseLayer.call of <stylegan.DenseLayer object at 0x7fd929cf8bd0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method DenseLayer.call of <stylegan.DenseLayer object at 0x7fd929cf8bd0>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method DenseLayer.call of <stylegan.DenseLayer object at 0x7fd929cf8bd0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method DenseLayer.call of <stylegan.DenseLayer object at 0x7fd929cf8bd0>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method StyleModApply.call of <stylegan.StyleModApply object at 0x7fd95a07fb10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method StyleModApply.call of <stylegan.StyleModApply object at 0x7fd95a07fb10>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method StyleModApply.call of <stylegan.StyleModApply object at 0x7fd95a07fb10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method StyleModApply.call of <stylegan.StyleModApply object at 0x7fd95a07fb10>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method Conv2d.call of <stylegan.Conv2d object at 0x7fd98be11610>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv2d.call of <stylegan.Conv2d object at 0x7fd98be11610>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Conv2d.call of <stylegan.Conv2d object at 0x7fd98be11610>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv2d.call of <stylegan.Conv2d object at 0x7fd98be11610>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound
> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method StridedSlice.call of <stylegan.StridedSlice object at 0x7fd98bc05210>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method DenseLayer.call of <stylegan.DenseLayer object at 0x7fd96b4858d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method DenseLayer.call of <stylegan.DenseLayer object at 0x7fd96b4858d0>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method DenseLayer.call of <stylegan.DenseLayer object at 0x7fd96b4858d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method DenseLayer.call of <stylegan.DenseLayer object at 0x7fd96b4858d0>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method StyleModApply.call of <stylegan.StyleModApply object at 0x7fd94a7bce90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method StyleModApply.call of <stylegan.StyleModApply object at 0x7fd94a7bce90>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method StyleModApply.call of <stylegan.StyleModApply object at 0x7fd94a7bce90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method StyleModApply.call of <stylegan.StyleModApply object at 0x7fd94a7bce90>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method Conv2d.call of <stylegan.Conv2d object at 0x7fd98bc41750>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv2d.call of <stylegan.Conv2d object at 0x7fd98bc41750>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Conv2d.call of <stylegan.Conv2d object at 0x7fd98bc41750>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv2d.call of <stylegan.Conv2d object at 0x7fd98bc41750>>: AttributeError: module 'gast' has no attribute 'Num'
# ...
# WARNING: Entity <bound method DenseLayer.call of <stylegan.DenseLayer object at 0x7fd92ab7d910>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method DenseLayer.call of <stylegan.DenseLayer object at 0x7fd92ab7d910>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method StyleModApply.call of <stylegan.StyleModApply object at 0x7fd98c288c10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method StyleModApply.call of <stylegan.StyleModApply object at 0x7fd98c288c10>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method StyleModApply.call of <stylegan.StyleModApply object at 0x7fd98c288c10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method StyleModApply.call of <stylegan.StyleModApply object at 0x7fd98c288c10>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method Conv2d_transpose.call of <stylegan.Conv2d_transpose object at 0x7fd95acfae50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv2d_transpose.call of <stylegan.Conv2d_transpose object at 0x7fd95acfae50>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Conv2d_transpose.call of <stylegan.Conv2d_transpose object at 0x7fd95acfae50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv2d_transpose.call of <stylegan.Conv2d_transpose object at 0x7fd95acfae50>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method ApplyNoise.call of <stylegan.ApplyNoise object at 0x7fd95ad42290>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method ApplyNoise.call of <stylegan.ApplyNoise object at 0x7fd95ad42290>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method ApplyNoise.call of <stylegan.ApplyNoise object at 0x7fd95ad42290>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method ApplyNoise.call of <stylegan.ApplyNoise object at 0x7fd95ad42290>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method ApplyBias.call of <stylegan.ApplyBias object at 0x7fd968bbd610>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method ApplyBias.call of <stylegan.ApplyBias object at 0x7fd968bbd610>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method ApplyBias.call of <stylegan.ApplyBias object at 0x7fd968bbd610>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method ApplyBias.call of <stylegan.ApplyBias object at 0x7fd968bbd610>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method InstanceNorm.call of <stylegan.InstanceNorm object at 0x7fd95ad2a510>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method InstanceNorm.call of <stylegan.InstanceNorm object at 0x7fd95ad2a510>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method InstanceNorm.call of <stylegan.InstanceNorm object at 0x7fd95ad2a510>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method InstanceNorm.call of <stylegan.InstanceNorm object at 0x7fd95ad2a510>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method StridedSlice.call of <stylegan.StridedSlice object at 0x7fd979fefe90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method StridedSlice.call of <stylegan.StridedSlice object at 0x7fd979fefe90>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method StridedSlice.call of <stylegan.StridedSlice object at 0x7fd979fefe90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method StridedSlice.call of <stylegan.StridedSlice object at 0x7fd979fefe90>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method DenseLayer.call of <stylegan.DenseLayer object at 0x7fd95ad52b90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method DenseLayer.call of <stylegan.DenseLayer object at 0x7fd95ad52b90>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method DenseLayer.call of <stylegan.DenseLayer object at 0x7fd95ad52b90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method DenseLayer.call of <stylegan.DenseLayer object at 0x7fd95ad52b90>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method StyleModApply.call of <stylegan.StyleModApply object at 0x7fd95ad426d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method StyleModApply.call of <stylegan.StyleModApply object at 0x7fd95ad426d0>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method StyleModApply.call of <stylegan.StyleModApply object at 0x7fd95ad426d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method StyleModApply.call of <stylegan.StyleModApply object at 0x7fd95ad426d0>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method Conv2d.call of <stylegan.Conv2d object at 0x7fd979326d10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv2d.call of <stylegan.Conv2d object at 0x7fd979326d10>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Conv2d.call of <stylegan.Conv2d object at 0x7fd979326d10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv2d.call of <stylegan.Conv2d object at 0x7fd979326d10>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method ApplyNoise.call of <stylegan.ApplyNoise object at 0x7fd95ad42750>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method ApplyNoise.call of <stylegan.ApplyNoise object at 0x7fd95ad42750>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method ApplyNoise.call of <stylegan.ApplyNoise object at 0x7fd95ad42750>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method ApplyNoise.call of <stylegan.ApplyNoise object at 0x7fd95ad42750>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method ApplyBias.call of <stylegan.ApplyBias object at 0x7fd979334750>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method ApplyBias.call of <stylegan.ApplyBias object at 0x7fd979334750>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method ApplyBias.call of <stylegan.ApplyBias object at 0x7fd979334750>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method ApplyBias.call of <stylegan.ApplyBias object at 0x7fd979334750>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method InstanceNorm.call of <stylegan.InstanceNorm object at 0x7fd95ad75dd0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method InstanceNorm.call of <stylegan.InstanceNorm object at 0x7fd95ad75dd0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method InstanceNorm.call of <stylegan.InstanceNorm object at 0x7fd95ad75dd0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method InstanceNorm.call of <stylegan.InstanceNorm object at 0x7fd95ad75dd0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method StridedSlice.call of <stylegan.StridedSlice object at 0x7fd979334a10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method StridedSlice.call of <stylegan.StridedSlice object at 0x7fd979334a10>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method StridedSlice.call of <stylegan.StridedSlice object at 0x7fd979334a10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method StridedSlice.call of <stylegan.StridedSlice object at 0x7fd979334a10>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method DenseLayer.call of <stylegan.DenseLayer object at 0x7fd92b586b90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method DenseLayer.call of <stylegan.DenseLayer object at 0x7fd92b586b90>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method DenseLayer.call of <stylegan.DenseLayer object at 0x7fd92b586b90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method DenseLayer.call of <stylegan.DenseLayer object at 0x7fd92b586b90>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method StyleModApply.call of <stylegan.StyleModApply object at 0x7fd968bb9d90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method StyleModApply.call of <stylegan.StyleModApply object at 0x7fd968bb9d90>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method StyleModApply.call of <stylegan.StyleModApply object at 0x7fd968bb9d90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method StyleModApply.call of <stylegan.StyleModApply object at 0x7fd968bb9d90>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method Conv2d.call of <stylegan.Conv2d object at 0x7fd96b42ad10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv2d.call of <stylegan.Conv2d object at 0x7fd96b42ad10>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Conv2d.call of <stylegan.Conv2d object at 0x7fd96b42ad10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv2d.call of <stylegan.Conv2d object at 0x7fd96b42ad10>>: AttributeError: module 'gast' has no attribute 'Num'
# Model created.

# %% [markdown]
# # Load best StyleGAN weights (Gs) from disk

# %%
import pickle
all_weights = pickle.load(open('gs_weights.pkl', 'rb'))
print('Weights loaded to memory.')

from stylegan import copy_weights_to_keras_model
copy_weights_to_keras_model(model.model_mapping, all_weights)
copy_weights_to_keras_model(model.model_synthesis, all_weights)
# Out:
# Weights loaded to memory.
# .........Total number of parameters copied: 2101760
# ...........................................................................................Total number of parameters copied: 26906963

# %%
# %matplotlib inline
y = model.generate_sample(is_visualize=True)
# Out:
# WARNING:tensorflow:Entity <bound method StyleGAN_G.call of <stylegan.StyleGAN_G object at 0x7fd94a0e7ad0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound
> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method DenseLayer.call of <stylegan.DenseLayer object at 0x7fd9795c6690>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method Truncation.call of <stylegan.Truncation object at 0x7fd929cf2f10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Truncation.call of <stylegan.Truncation object at 0x7fd929cf2f10>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Truncation.call of <stylegan.Truncation object at 0x7fd929cf2f10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Truncation.call of <stylegan.Truncation object at 0x7fd929cf2f10>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Const.call of <stylegan.Const object at 0x7fd94a759dd0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Const.call of <stylegan.Const object at 0x7fd94a759dd0>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Const.call of <stylegan.Const object at 0x7fd94a759dd0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Const.call of <stylegan.Const object at 0x7fd94a759dd0>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method RandomNoise.call of <stylegan.RandomNoise object at 0x7fd97960af10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method RandomNoise.call of <stylegan.RandomNoise object at 0x7fd97960af10>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method RandomNoise.call of <stylegan.RandomNoise object at 0x7fd97960af10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method RandomNoise.call of <stylegan.RandomNoise object at 0x7fd97960af10>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method ApplyNoise.call of <stylegan.ApplyNoise object at 0x7fd96b466bd0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method ApplyNoise.call of <stylegan.ApplyNoise object at 0x7fd96b466bd0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method ApplyNoise.call of <stylegan.ApplyNoise object at 0x7fd96b466bd0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method ApplyNoise.call of <stylegan.ApplyNoise object at 0x7fd96b466bd0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method ApplyBias.call of <stylegan.ApplyBias object at 0x7fd9795c0890>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method ApplyBias.call of <stylegan.ApplyBias object at 0x7fd9795c0890>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method ApplyBias.call of <stylegan.ApplyBias object at 0x7fd9795c0890>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method ApplyBias.call of <stylegan.ApplyBias object at 0x7fd9795c0890>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method StridedSlice.call of <stylegan.StridedSlice object at 0x7fd929cf2590>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method StridedSlice.call of <stylegan.StridedSlice object at 0x7fd929cf2590>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method StridedSlice.call of <stylegan.StridedSlice object at 0x7fd929cf2590>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method StridedSlice.call of <stylegan.StridedSlice object at 0x7fd929cf2590>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method InstanceNorm.call of <stylegan.InstanceNorm object at 0x7fd96b485390>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method InstanceNorm.call of <stylegan.InstanceNorm object at 0x7fd96b485390>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method InstanceNorm.call of <stylegan.InstanceNorm object at 0x7fd96b485390>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method InstanceNorm.call of <stylegan.InstanceNorm object at 0x7fd96b485390>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method DenseLayer.call of <stylegan.DenseLayer object at 0x7fd929cf8bd0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method DenseLayer.call of <stylegan.DenseLayer object at 0x7fd929cf8bd0>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method DenseLayer.call of <stylegan.DenseLayer object at 0x7fd929cf8bd0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method DenseLayer.call of <stylegan.DenseLayer object at 0x7fd929cf8bd0>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method StyleModApply.call of <stylegan.StyleModApply object at 0x7fd95a07fb10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method StyleModApply.call of <stylegan.StyleModApply object at 0x7fd95a07fb10>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method StyleModApply.call of <stylegan.StyleModApply object at 0x7fd95a07fb10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method StyleModApply.call of <stylegan.StyleModApply object at 0x7fd95a07fb10>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method Conv2d.call of <stylegan.Conv2d object at 0x7fd98be11610>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv2d.call of <stylegan.Conv2d object at 0x7fd98be11610>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Conv2d.call of <stylegan.Conv2d object at 0x7fd98be11610>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv2d.call of <stylegan.Conv2d object at 0x7fd98be11610>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method RandomNoise.call of <stylegan.RandomNoise object at 0x7fd929cf8c10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method RandomNoise.call of <stylegan.RandomNoise object at 0x7fd929cf8c10>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method RandomNoise.call of <stylegan.RandomNoise object at 0x7fd929cf8c10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method RandomNoise.call of <stylegan.RandomNoise object at 0x7fd929cf8c10>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound
>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method StyleModApply.call of <stylegan.StyleModApply object at 0x7fd97961ba90>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method StyleModApply.call of <stylegan.StyleModApply object at 0x7fd97961ba90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method StyleModApply.call of <stylegan.StyleModApply object at 0x7fd97961ba90>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method Conv2d.call of <stylegan.Conv2d object at 0x7fd98bc412d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv2d.call of <stylegan.Conv2d object at 0x7fd98bc412d0>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Conv2d.call of <stylegan.Conv2d object at 0x7fd98bc412d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv2d.call of <stylegan.Conv2d object at 0x7fd98bc412d0>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method RandomNoise.call of <stylegan.RandomNoise object at 0x7fd9795c6e90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method RandomNoise.call of <stylegan.RandomNoise object at 0x7fd9795c6e90>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method RandomNoise.call of <stylegan.RandomNoise object at 0x7fd9795c6e90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method RandomNoise.call of <stylegan.RandomNoise object at 0x7fd9795c6e90>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method ApplyNoise.call of <stylegan.ApplyNoise object at 0x7fd94db409d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method ApplyNoise.call of <stylegan.ApplyNoise object at 0x7fd94db409d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method ApplyNoise.call of <stylegan.ApplyNoise object at 0x7fd94db409d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method ApplyNoise.call of <stylegan.ApplyNoise object at 0x7fd94db409d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method ApplyBias.call of <stylegan.ApplyBias object at 0x7fd98bc3f850>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method ApplyBias.call of <stylegan.ApplyBias object at 0x7fd98bc3f850>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method ApplyBias.call of <stylegan.ApplyBias object at 0x7fd98bc3f850>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method ApplyBias.call of <stylegan.ApplyBias object at 0x7fd98bc3f850>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method StridedSlice.call of <stylegan.StridedSlice object at 0x7fd979efc0d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method StridedSlice.call of <stylegan.StridedSlice object at 0x7fd979efc0d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method StridedSlice.call of <stylegan.StridedSlice object at 0x7fd979efc0d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method StridedSlice.call of <stylegan.StridedSlice object at 0x7fd979efc0d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method InstanceNorm.call of <stylegan.InstanceNorm object at 0x7fd94db5fed0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method InstanceNorm.call of <stylegan.InstanceNorm object at 0x7fd94db5fed0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method InstanceNorm.call of <stylegan.InstanceNorm object at 0x7fd94db5fed0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method InstanceNorm.call of <stylegan.InstanceNorm object at 0x7fd94db5fed0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method DenseLayer.call of <stylegan.DenseLayer object at 0x7fd979f01210>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method DenseLayer.call of <stylegan.DenseLayer object at 0x7fd979f01210>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method DenseLayer.call of <stylegan.DenseLayer object at 0x7fd979f01210>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method DenseLayer.call of <stylegan.DenseLayer object at 0x7fd979f01210>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method StyleModApply.call of <stylegan.StyleModApply object at 0x7fd979efc750>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method StyleModApply.call of <stylegan.StyleModApply object at 0x7fd979efc750>>: AttributeError: module 'gast' has no attribute 'Num'
# ...
# WARNING: Entity <bound method Conv2d_transpose.call of <stylegan.Conv2d_transpose object at 0x7fd95acfae50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv2d_transpose.call of <stylegan.Conv2d_transpose object at 0x7fd95acfae50>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method RandomNoise.call of <stylegan.RandomNoise object at 0x7fd96b451850>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method RandomNoise.call of <stylegan.RandomNoise object at 0x7fd96b451850>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method RandomNoise.call of <stylegan.RandomNoise object at 0x7fd96b451850>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method RandomNoise.call of <stylegan.RandomNoise object at 0x7fd96b451850>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method ApplyNoise.call of <stylegan.ApplyNoise object at 0x7fd95ad42290>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method ApplyNoise.call of <stylegan.ApplyNoise object at 0x7fd95ad42290>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method ApplyNoise.call of <stylegan.ApplyNoise object at 0x7fd95ad42290>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method ApplyNoise.call of <stylegan.ApplyNoise object at 0x7fd95ad42290>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method ApplyBias.call of <stylegan.ApplyBias object at 0x7fd968bbd610>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method ApplyBias.call of <stylegan.ApplyBias object at 0x7fd968bbd610>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method ApplyBias.call of <stylegan.ApplyBias object at 0x7fd968bbd610>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method ApplyBias.call of <stylegan.ApplyBias object at 0x7fd968bbd610>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method StridedSlice.call of <stylegan.StridedSlice object at 0x7fd979fefe90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method StridedSlice.call of <stylegan.StridedSlice object at 0x7fd979fefe90>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method StridedSlice.call of <stylegan.StridedSlice object at 0x7fd979fefe90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method StridedSlice.call of <stylegan.StridedSlice object at 0x7fd979fefe90>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method InstanceNorm.call of <stylegan.InstanceNorm object at 0x7fd95ad2a510>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method InstanceNorm.call of <stylegan.InstanceNorm object at 0x7fd95ad2a510>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method InstanceNorm.call of <stylegan.InstanceNorm object at 0x7fd95ad2a510>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method InstanceNorm.call of <stylegan.InstanceNorm object at 0x7fd95ad2a510>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method DenseLayer.call of <stylegan.DenseLayer object at 0x7fd95ad52b90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method DenseLayer.call of <stylegan.DenseLayer object at 0x7fd95ad52b90>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method DenseLayer.call of <stylegan.DenseLayer object at 0x7fd95ad52b90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method DenseLayer.call of <stylegan.DenseLayer object at 0x7fd95ad52b90>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method StyleModApply.call of <stylegan.StyleModApply object at 0x7fd95ad426d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method StyleModApply.call of <stylegan.StyleModApply object at 0x7fd95ad426d0>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method StyleModApply.call of <stylegan.StyleModApply object at 0x7fd95ad426d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method StyleModApply.call of <stylegan.StyleModApply object at 0x7fd95ad426d0>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method Conv2d.call of <stylegan.Conv2d object at 0x7fd979326d10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv2d.call of <stylegan.Conv2d object at 0x7fd979326d10>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Conv2d.call of <stylegan.Conv2d object at 0x7fd979326d10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv2d.call of <stylegan.Conv2d object at 0x7fd979326d10>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method RandomNoise.call of <stylegan.RandomNoise object at 0x7fd98bdfa690>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method RandomNoise.call of <stylegan.RandomNoise object at 0x7fd98bdfa690>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method RandomNoise.call of <stylegan.RandomNoise object at 0x7fd98bdfa690>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method RandomNoise.call of <stylegan.RandomNoise object at 0x7fd98bdfa690>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method ApplyNoise.call of <stylegan.ApplyNoise object at 0x7fd95ad42750>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method ApplyNoise.call of <stylegan.ApplyNoise object at 0x7fd95ad42750>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method ApplyNoise.call of <stylegan.ApplyNoise object at 0x7fd95ad42750>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method ApplyNoise.call of <stylegan.ApplyNoise object at 0x7fd95ad42750>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method ApplyBias.call of <stylegan.ApplyBias object at 0x7fd979334750>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method ApplyBias.call of <stylegan.ApplyBias object at 0x7fd979334750>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method ApplyBias.call of <stylegan.ApplyBias object at 0x7fd979334750>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method ApplyBias.call of <stylegan.ApplyBias object at 0x7fd979334750>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method StridedSlice.call of <stylegan.StridedSlice object at 0x7fd979334a10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method StridedSlice.call of <stylegan.StridedSlice object at 0x7fd979334a10>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method StridedSlice.call of <stylegan.StridedSlice object at 0x7fd979334a10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method StridedSlice.call of <stylegan.StridedSlice object at 0x7fd979334a10>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method InstanceNorm.call of <stylegan.InstanceNorm object at 0x7fd95ad75dd0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method InstanceNorm.call of <stylegan.InstanceNorm object at 0x7fd95ad75dd0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method InstanceNorm.call of <stylegan.InstanceNorm object at 0x7fd95ad75dd0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method InstanceNorm.call of <stylegan.InstanceNorm object at 0x7fd95ad75dd0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method DenseLayer.call of <stylegan.DenseLayer object at 0x7fd92b586b90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method DenseLayer.call of <stylegan.DenseLayer object at 0x7fd92b586b90>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method DenseLayer.call of <stylegan.DenseLayer object at 0x7fd92b586b90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method DenseLayer.call of <stylegan.DenseLayer object at 0x7fd92b586b90>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method StyleModApply.call of <stylegan.StyleModApply object at 0x7fd968bb9d90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method StyleModApply.call of <stylegan.StyleModApply object at 0x7fd968bb9d90>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method StyleModApply.call of <stylegan.StyleModApply object at 0x7fd968bb9d90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method StyleModApply.call of <stylegan.StyleModApply object at 0x7fd968bb9d90>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method Conv2d.call of <stylegan.Conv2d object at 0x7fd96b42ad10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv2d.call of <stylegan.Conv2d object at 0x7fd96b42ad10>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Conv2d.call of <stylegan.Conv2d object at 0x7fd96b42ad10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Conv2d.call of <stylegan.Conv2d object at 0x7fd96b42ad10>>: AttributeError: module 'gast' has no attribute 'Num'

# %% [markdown]
# # Test saving and loading from and to `tf.keras.Model` weights

# %%
model.save_weights('stylegan.h5')
model.load_weights('stylegan.h5')

y2 = model.generate_sample(3, is_visualize=True)
# Out:
# (1, 1024, 1024, 3) 0.0 1.0

# %% [markdown]
# # Test discriminator (D)

# %%
from stylegan import StyleGAN_D

# Load best weights (D) into memory
sess = tf.get_default_session()    
all_weights = collections.OrderedDict()
with sess.as_default():  
    for i, (key, weight_tensor) in enumerate(_D.vars.items()):        
        all_weights[key] = weight_tensor.eval()
        print('.', end='')
print(' ({}) weights found. '.format(len(all_weights)))

d_model = StyleGAN_D()
copy_weights_to_keras_model(d_model.model, all_weights)

# %%
d_model.predict( y.transpose([0, 3, 1, 2]) )
# Out:
# array([[-6.7732077]], dtype=float32)

# %% [markdown]
# # (Optional) visualize the model graph

# %%
import tensorflow as tf
from IPython.display import clear_output, Image, display, HTML
import numpy as np    

tf.reset_default_graph()
model = StyleGAN_G()

def strip_consts(graph_def, max_const_size=32):
    """Strip large constant values from graph_def."""
    strip_def = tf.GraphDef()
    for n0 in graph_def.node:
        n = strip_def.node.add() 
        n.MergeFrom(n0)
        if n.op == 'Const':
            tensor = n.attr['value'].tensor
            size = len(tensor.tensor_content)
            if size > max_const_size:
                tensor.tensor_content = "<stripped %d bytes>"%size
    return strip_def

def show_graph(graph_def, max_const_size=32):
    """Visualize TensorFlow graph."""
    if hasattr(graph_def, 'as_graph_def'):
        graph_def = graph_def.as_graph_def()
    strip_def = graph_def
    code = """
        <script>
          function load() {{
            document.getElementById("{id}").pbtxt = {data};
          }}
        </script>
        <link rel="import" href="https://tensorboard.appspot.com/tf-graph-basic.build.html" onload=load()>
        <div style="height:900px">
          <tf-graph-basic id="{id}"></tf-graph-basic>
        </div>
    """.format(data=repr(str(strip_def)), id='graph'+str(np.random.rand()))

    iframe = """
        <iframe seamless style="width:1400px;height:900px;border:0" srcdoc="{}"></iframe>
    """.format(code.replace('"', '&quot;'))
    display(HTML(iframe))
    
show_graph(tf.get_default_graph().as_graph_def())
